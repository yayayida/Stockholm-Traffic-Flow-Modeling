# %% [markdown]
# <a href="https://colab.research.google.com/github/yayayida/Stockholm-Traffic-Flow-Modeling/blob/Revised-MainModel/NewMainModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Python Environment
# Run the cells below to make sure that you are in correct python environment to run the project.
#
# *Required*
# - **Python 3.9.***
# - **Conda ENV - Urban**

# %%
# !pip install haversine
# Out:
# Requirement already satisfied: haversine in /usr/local/lib/python3.12/dist-packages (2.9.0)

# %%
# !python -V
import os
if 'CONDA_DEFAULT_ENV' in os.environ:
    print("Conda ENV - ", os.environ['CONDA_DEFAULT_ENV'])
else:
    print("Conda ENV - Not set (might not be in a conda environment or variable not exported)")
# Out:
# Python 3.12.12
# Conda ENV - Not set (might not be in a conda environment or variable not exported)

# %% [markdown]
# ## Python Libraries
# All the libraries imported are installed within the conda environment. If the library is not installed, it will show an error.

# %%
import Landuse
#from Demand import Demand
import Network
import Assignment
from Visualization import Visualize
from Effect import Effect
import numpy as np
import pandas as pd

# %% [markdown]
# ## Variable setting

# %%
######### VARIABLES ############
fuel_cost = 12      # fuel cost 12 sek/liter
fuel_con = 0.085    # fuel consumption is 0.085 l/km
cost_km = fuel_cost * fuel_con
carparking = 10      # Cost of Parking
transitprice = 30   # Cost of Transit
penalty_intra_car = 30

# %% [markdown]
# ## Parameter setting

# %%
######### PARAMETERS ############
alpha = 0.5        # constant for car mode
beta_car = -0.08  # parameter for car travel time
gamma_car = -0.05   # parameter for car travel cost
beta_inv = -0.05    # parameter for transit in-vehile travel time
beta_wait = -0.08    # parameter for transit total waiting time
gamma_pt = -0.05  # parameter for transit ticket price
alpha_slow = 0.1  #parameter for slow mode
phi_dist = -0.5    # parameter for slow mode time
mu = 0.5            # Logsum weight
theta = 1           # parameter for destination choice
param = [alpha, beta_car, gamma_car, beta_inv, beta_wait, gamma_pt, alpha_slow, phi_dist, mu, theta] # to pass the parameter value to demand function as a list
vot_car = beta_car/gamma_car        # value of time for car
vot_in = beta_inv/gamma_pt         # value of in-vehile travel time for transit
vot_wait = beta_wait/gamma_pt      # value of total waiting time for transit
constant = 0.2      # alternative specific constant for owning a car
income = 0.003      # parameter for income
dummy = -0.5        # dummy for residency in the inner city
param_carown = [constant, income, dummy] # to pass the parameter value to landuse function as a list

# %% [markdown]
# ## Import data

# %%
# Load landuse and zone information
landuse, zones = Landuse.get_landuse_and_zones(param_carown)

# Origin and Destination dictionary
origin      = dict(zip(landuse.area, landuse.index))
destination = origin.copy()

# Create Graph network for car and transit
G_car = Network.RoadNetwork(zones.transpose())
G_pt = Network.TransitNetwork(zones.transpose())

# %% [markdown]
# ## Initialize the network

# %%
# Initialize the network
demand = np.ones((len(landuse), len(landuse)))
# Now add intra-zonal links
G_car, G_pt = Assignment.add_intra_zonal_links(
    G_car,
    G_pt,
    zones=zones,
    landuse=landuse,
    vot_car=vot_car,
    vot_pt=vot_in,
    cost_km=cost_km,
    transitprice=transitprice,
    penalty_intra_car=penalty_intra_car
)

# Run assignment
G_start_car = Assignment.RouteAssignment(np.asarray(demand), G_car, origin, destination,vot_car,cost_km,penalty_intra_car)
G_start_pt = Assignment.TransitAssignment(np.asarray(demand), G_pt, origin, destination,vot_in,vot_wait)
car_time_0, car_cost_0, dist = Assignment.Skim_car(G_start_car, origin, destination, penalty_intra_car)
invt, waitt = Assignment.Skim_pt(G_start_pt, origin, destination)
# Out:
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times    Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  --------  ----------------------
#     1                     1934.15                       1934.15         0                       0
# ---------------------------------------------------------------------------------------------
# assignment: k = 2 relgap = 0.000000, AEC = 0.000000

# %% [markdown]
# ## Demand funtion example with fixed probability

# %%
def Demand_fix (car_time, car_cost, car_park, inv_time, wait_time, pt_price, dist, parameter, pop, emp, own):

    # the following parameters will be used for utility functions
    alpha = parameter[0]
    beta_car = parameter[1]
    gamma_car = parameter[2]
    beta_inv = parameter[3]
    beta_wait = parameter[4]
    gamma_pt = parameter[5]
    phi_dist = parameter[6]
    mu = parameter[7]
    theta = parameter[8]

    pop = np.asmatrix(pop).transpose()
    own = np.asmatrix(own).transpose()
    emp = np.asmatrix(emp)

    # assuming a fixed probability
    Pcar = np.ones((len(pop), len(pop))) *(0.4/len(pop))
    Ppt  = np.ones((len(pop), len(pop)))  *(0.4/len(pop))
    Pslow= np.ones((len(pop), len(pop)))*(0.2/len(pop))

    # calculating the demand
    Vol_car  = np.multiply(pop,Pcar)
    Vol_pt   = np.multiply(pop,Ppt)
    Vol_slow = np.multiply(pop,Pslow)
    EU = 0

    return (Vol_car, Vol_pt, Vol_slow, EU)

# %% [markdown]
# ## Equilibrium

# %%
## Suggested Equilibrium cell (also based on the Project file)
# calculate demand
maxiter = 100       # maxium number of iterations in finding the equilibrium
maxdiff = 0.01      # or if the travel time converges to the point where difference in travel time between iterations is smaller than 0.01
car_time=car_time_0
car_cost=car_cost_0
for iter in range(maxiter):
    print("\n")
    car_time_old = car_time
    car_cost_old = car_cost

    # Here, you can change to your demand funtion
    v_car, v_pt, v_slow, EU = Demand_fix(car_time,
                         car_cost,
                         carparking,
                         invt,
                         waitt,
                         transitprice,
                         dist,
                         param,
                         np.array(landuse['pop']),
                         np.array(landuse['emp']),
                         np.array(landuse['car_ownership']))
    # assign the traffic based on the demand to get the new car time, cost, and distance
    print(f"the car demand to routeassignment: {np.sum(v_car)}")
    G_next_car = Assignment.RouteAssignment(np.asarray(v_car), G_car, origin, destination,vot_car,cost_km, penalty_intra_car)
    G_next_pt = Assignment.TransitAssignment(np.asarray(v_pt), G_pt, origin, destination,vot_in,vot_wait)
    car_time, car_cost, dist = Assignment.Skim_car(G_next_car, origin, destination, penalty_intra_car)

    # calculate car_time values with 0.2 share of new values (from assignemet.skim_car) and
    # 0.8 share of the old car time values
    car_time = car_time * 0.2 + car_time_old * 0.8
    car_cost = car_cost * 0.2 + car_cost_old * 0.8

    # define the average error (e.g. 0.2) for convergence, and if it is met, make (stop = 1)
    diff = (np.mean((np.abs(car_time-car_time_old))))
    print(f"Iteration: {iter}\tDifference in travel time:{diff}")
    if (diff < maxdiff) or (iter>=maxiter):
        break
# Out:
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 0	Difference in travel time:2.589605020486873
#
#
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 1	Difference in travel time:2.0716840163894985
#
#
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 2	Difference in travel time:1.657347213111599
#
#
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 3	Difference in travel time:1.3258777704892792
#
#
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 4	Difference in travel time:1.0607022163914237
#
#
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 5	Difference in travel time:0.848561773113139
#
#
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 6	Difference in travel time:0.6788494184905111
#
#
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 7	Difference in travel time:0.5430795347924091
#
#
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 8	Difference in travel time:0.43446362783392717
#
#
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 9	Difference in travel time:0.34757090226714177
#
#
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 10	Difference in travel time:0.27805672181371366
#
#
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 11	Difference in travel time:0.22244537745097095
#
#
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 12	Difference in travel time:0.17795630196077641
#
#
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 13	Difference in travel time:0.1423650415686213
#
#
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 14	Difference in travel time:0.11389203325489715
#
#
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 15	Difference in travel time:0.09111362660391781
#
#
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 16	Difference in travel time:0.07289090128313429
#
#
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 17	Difference in travel time:0.05831272102650734
#
#
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 18	Difference in travel time:0.04665017682120587
#
#
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 19	Difference in travel time:0.03732014145696468
#
#
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 20	Difference in travel time:0.029856113165571713
#
#
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 21	Difference in travel time:0.023884890532457452
#
#
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 22	Difference in travel time:0.019107912425965833
#
#
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 23	Difference in travel time:0.015286329940772765
#
#
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 24	Difference in travel time:0.012229063952617965
#
#
# the car demand to routeassignment: 320000.0
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times     Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ---------  ----------------------
#     1                 1.20539e+07                   1.10732e+07  0.0885717                  295418
#     2                 1.10793e+07                   1.08657e+07  0.0196656                  147600
#     3                 1.10666e+07                   1.09081e+07  0.0145326                  127258
#     4                 1.10623e+07                   1.09327e+07  0.0118518                  121914
#     5                 1.10623e+07                   1.09333e+07  0.0117942                  121795
#     6                 1.10622e+07                   1.09339e+07  0.0117368                  121676
#     7                 1.10621e+07                   1.09344e+07  0.0116796                  121557
#     8                 1.10621e+07                   1.0935e+07   0.0116225                  121438
#     9                 1.1062e+07                    1.09355e+07  0.0115655                  121320
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.011565, AEC = 0.395234
# Iteration: 25	Difference in travel time:0.00978325116209466

# %% [markdown]
# ## RESULT
# The cells shows the result of the 4-step model.

# %%
# output result in a table, you can specify what output might be useful
# Hint: what is the total number of trips?
pd.options.display.float_format = '{: ,.0f}'.format
from Effect import Effect
Effect(v_car, v_pt, v_slow, dist, carparking, transitprice, EU)
# Out:
#                     INFORMATION
# Car Trips                320000
# Transit Trips            320000
# Slow Trips               160000
# Total trips              800000
# Distance Travelled        58155
# Expected Utility              0

# %%
# below the car flow and transit flow are plotted in seperate layer, you can activate/deactivate layers
Visualize(G_next_car, G_next_pt, zones, title="REULST FOR 4-STEP MODEL")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9afeb0c86ab776dd43c6da88741031da {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#                 &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;REULST FOR 4-STEP MODEL&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9afeb0c86ab776dd43c6da88741031da&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9afeb0c86ab776dd43c6da88741031da = L.map(
#                 &quot;map_9afeb0c86ab776dd43c6da88741031da&quot;,
#                 {
#                     center: [59.33429725815369, 18.074580506480082],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_9afeb0c86ab776dd43c6da88741031da);
#
#
#
#
#
#             var tile_layer_13588edd7ed95a54920cc2ce11866fbc = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_13588edd7ed95a54920cc2ce11866fbc.addTo(map_9afeb0c86ab776dd43c6da88741031da);
#
#
#             map_9afeb0c86ab776dd43c6da88741031da.fitBounds(
#                 [[59.22725242579792, 17.760692003425188], [59.44134209050946, 18.388469009534976]],
#                 {}
#             );
#
#
#         function geo_json_63bbe783a5bddd0d4eae207275616be7_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_63bbe783a5bddd0d4eae207275616be7_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_63bbe783a5bddd0d4eae207275616be7_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_63bbe783a5bddd0d4eae207275616be7_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_63bbe783a5bddd0d4eae207275616be7_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_63bbe783a5bddd0d4eae207275616be7.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_63bbe783a5bddd0d4eae207275616be7_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_63bbe783a5bddd0d4eae207275616be7 = L.geoJson(null, {
#                 onEachFeature: geo_json_63bbe783a5bddd0d4eae207275616be7_onEachFeature,
#
#                 style: geo_json_63bbe783a5bddd0d4eae207275616be7_styler,
#                 pointToLayer: geo_json_63bbe783a5bddd0d4eae207275616be7_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_63bbe783a5bddd0d4eae207275616be7_add (data) {
#             geo_json_63bbe783a5bddd0d4eae207275616be7
#                 .addData(data);
#         }
#             geo_json_63bbe783a5bddd0d4eae207275616be7_add({&quot;bbox&quot;: [17.760692003425188, 59.22725242579792, 18.388469009534976, 59.44134209050946], &quot;features&quot;: [{&quot;bbox&quot;: [17.888449229398596, 59.33936467432812, 18.05854435314131, 59.440283880183806], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[17.99926189055947, 59.34097701581949], [17.998281666750778, 59.3407689948803], [17.996356534152998, 59.34144786207281], [17.993343631062963, 59.342432332102284], [17.99062030018352, 59.343277261094016], [17.989494882762237, 59.34354747977749], [17.988854306784262, 59.34370189512002], [17.988404075747276, 59.343808218465895], [17.987385806019535, 59.344103655629084], [17.985110002349966, 59.34452787

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

zones_gdf = gpd.read_file("zones.geojson")
fig, ax = plt.subplots(figsize=(10, 10))
zones_gdf.plot(ax=ax, color='lightgrey', edgecolor='black', alpha=0.5)

for idx, row in zones_gdf.iterrows():
    centroid = row.geometry.centroid
    ax.annotate(text=str(idx),
                xy=(centroid.x, centroid.y),
                horizontalalignment='center',
                color='red',
                weight='bold',
                fontsize=15)

plt.title("Stockholm Zones with ID Labels", fontsize=16)
plt.axis('off')
plt.show()

# %% [markdown]
# #Task I
# The main task is to construct a mode choice model when the destination choice is assumed given.
# We have learned that the utility is formulated as $U^i_{j,m}=V^i_{j,m}+\epsilon^i_{j,m}$, where $\epsilon^i_{j,m}$ is i.i.d gumble distributed. Individuals are assumed to act as if they were utility maximizers, i.e, choose the mode $m$ such that: $U^i_{j,m}\ge U^i_{j,m'}  \forall  m' \in \lbrace car,pt,slow \rbrace $
# The deterministic utilities of the transport modes is defined as follows
# \begin{align}
#   V^i_{j, \textrm{car}} &= \alpha + \beta_{\textrm{car}} t^i_{j,\text{car}} + \gamma_{\textrm{car}} c^i_{j,\text{car}} \nonumber,\\
#   V^i_{j,\textrm{pt}} &= \beta_{\textrm{inv}} t^i_{j,\textrm{inv}} + \beta_{\textrm{wait}} t^i_{j,\textrm{wait}} + \gamma_{\textrm{pt}} c^i_{j,\text{pt}}, \nonumber\\
#   V^i_{j, \textrm{slow}} &= \phi d_{ij}. \nonumber
# \end{align}
#
# The probability of choosing a mode of transport $m$ condition on the chosen destination $j$ can be formulated as
# \begin{align}
# P^i(m|j) =\frac{e^{V^i_{j,m}}}{\sum_{m'\in M} e^{V^i_{j,m'}}}
# \end{align}

# %%
def Demand_logit(car_time, car_cost, car_park, inv_time, wait_time, pt_price, dist, parameter, pop, emp, own):

    # 1. Parameters Setting
    alpha = parameter[0]
    beta_car = parameter[1]
    gamma_car = parameter[2]
    beta_inv = parameter[3]
    beta_wait = parameter[4]
    gamma_pt = parameter[5]
    alpha_dist = parameter[6]
    phi_dist = parameter[7]
    mu = parameter[8]
    theta = parameter[9]

    pop = np.asmatrix(pop).transpose()
    own = np.asmatrix(own).transpose()
    emp = np.asmatrix(emp)

    # 2. Utility Functions for each mode
    # Car: V = alpha + beta*t + gamma*c
    Vcar  = parameter[0] + (parameter[1] * car_time) + (parameter[2] * (car_cost + car_park))
    # PT: V = beta*t_inv + beta*t_wait + gamma*c
    Vpt   = (parameter[3] * inv_time) + (parameter[4] * wait_time) + (parameter[5] * pt_price)
    # Slow: V = alpha_slow + phi*dist
    Vslow = parameter[6] + (parameter[7] * dist)

    # 3. Calculate P(m|j)
    denom = np.exp(Vcar) + np.exp(Vpt) + np.exp(Vslow)
    Pcar  = np.exp(Vcar) / denom
    Ppt   = np.exp(Vpt) / denom
    Pslow = np.exp(Vslow) / denom
    p_sum = Pcar + Ppt + Pslow
    # print("Check - Probability sum should be 1:", p_sum)

    # 4. Calculate the Demand
    Vol_car  = np.multiply(pop, Pcar)
    Vol_pt   = np.multiply(pop, Ppt)
    Vol_slow = np.multiply(pop, Pslow)
    EU = 0

    return (Vol_car, Vol_pt, Vol_slow, EU)

# %%
v_car, v_pt, v_slow, EU = Demand_logit(
        car_time, car_cost, carparking, invt, waitt,
        transitprice, dist, param,
        np.matrix(landuse['pop']),
        np.matrix(landuse['emp']),
        np.matrix(landuse['car_ownership']))
print(f"Total Car Demand: {np.sum(v_car):,.0f}")
print(f"Total PT Demand: {np.sum(v_pt):,.0f}")
print(f"Total Slow Demand: {np.sum(v_slow):,.0f}")
print(f"Expected Utility: {np.sum(EU):,.0f}")
# Out:
# Total Car Demand: 4,257,157
# Total PT Demand: 4,086,699
# Total Slow Demand: 456,143
# Expected Utility: 0

# %% [markdown]
# # Task II
# The main task is to construct a nested choice model, assuming that individuals make a joint decision on the destination choice and mode choice.
# The deterministic utility of destination choice is formulated as
# \begin{align}
# V_{j}=\theta ln (N_{employed}^j)
# \end{align}
#
# As the destination choice is assumed made at the upper level, meaning that the utility depends also on how "easy" to travel to the destination. The properties of the mode chice are then propagated to the destnation choice through the expected maximum utility (log-sum) of all modes:
# \begin{align}
# L^i_j = log \sum_m e^{V^i_{j,m}/ \mu}
# \end{align}
# multiplyed by a scale parameter $\mu$, $\mu L^i_j$ is the expected maximum utility of the lower nest of mode choices.
#
# The probability of choosing a destination $j$ is given by
# \begin{align}
# P(j)= \frac{e^{V_j+\mu L^i_j}}{\sum_{j'\in D} e^{V_j+\mu L^i_{j'}}}
# \end{align}
#
# Note that the mode choice probability need to be rewriten with the scale parameter
# \begin{align}
# P(m|j)=\frac{e^{V^i_{j,m}/ \mu}}{\sum_{m'\in M} e^{V^i_{j,m'}/ \mu}}
# \end{align}
#
# The probability of choosing mode $m$ from origin $i$ to destination $j$ is a joint probability, the product of the marginal probability $P(j)$ and the conditional probability $P(m|j) $
# \begin{align}
# P(m,j)=P(j)* P(m|j)
# \end{align}

# %%
def Demand_nestlogit(car_time, car_cost, car_park, inv_time, wait_time, pt_price, dist, parameter, pop, emp, own):

    # 1. Parameters Setting
    alpha_car   = parameter[0]
    beta_car    = parameter[1]
    gamma_car   = parameter[2]
    beta_inv    = parameter[3]
    beta_wait   = parameter[4]
    gamma_pt    = parameter[5]
    alpha_slow  = parameter[6]
    phi_dist    = parameter[7]
    mu          = parameter[8]
    theta       = parameter[9]

    pop = np.asmatrix(pop).transpose()
    own = np.asmatrix(own).transpose()
    emp = np.asmatrix(emp)

    # 2. Utility Functions for each mode and attractions
    # Car: V = alpha + beta*t + gamma*c
    Vcar  = parameter[0] + (parameter[1] * car_time) + (parameter[2] * (car_cost + car_park))
    # PT: V = beta*t_inv + beta*t_wait + gamma*c
    Vpt   = (parameter[3] * inv_time) + (parameter[4] * wait_time) + (parameter[5] * pt_price)
    # Slow: V = alpha_slow + phi*dist
    Vslow = parameter[6] + (parameter[7] * dist)
    # Attractions Vj:
    Vj  = parameter[9] * np.log(emp)

    # 3. Calculate Logsum (I) and P(m|j)
    exp_car = np.exp(Vcar / mu)
    exp_pt = np.exp(Vpt / mu)
    exp_slow = np.exp(Vslow / mu)
    denom = exp_car + exp_pt + exp_slow
    # Logsum
    Lj = np.log(denom + 1e-10)

    Pcar = exp_car / denom
    Ppt = exp_pt / denom
    Pslow = exp_slow / denom

    # 4. Calculate Marginal Probability from i to j
    V_dest = Vj + (mu * Lj)
    exp_dest = np.exp(V_dest)
    sum_dest = np.sum(exp_dest, axis=1)
    Pj = exp_dest / sum_dest
    p_sum = np.sum(Pj, axis = 1)
    # print("Result - Marginal Probability from i to j is:", Pj)
    # print("Check - Sum of Marginal Probability:", p_sum)

    # 5. Calculate Joint Probability
    Pcar_j = np.multiply(Pj, Pcar)
    Ppt_j  = np.multiply(Pj, Ppt)
    Pslow_j = np.multiply(Pj, Pslow)
    pj_sum = np.sum(Pcar_j, axis=1) + np.sum(Ppt_j, axis=1) + np.sum(Pslow_j, axis=1)
    # print("Check - Sum of Joint Probability:", pj_sum)

    # 6. Calculate the Demand
    Vol_car = np.multiply(pop, Pcar_j)
    Vol_pt = np.multiply(pop, Ppt_j)
    Vol_slow = np.multiply(pop, Pslow_j)
    Vol_sum = np.sum(Vol_car) + np.sum(Vol_pt) + np.sum(Vol_slow)
    print("Result - Volume of Car:", Vol_car.sum())
    print("Result - Volume of PT:", Vol_pt.sum())
    print("Result - Volume of Slow:", Vol_slow.sum())

    # 7. Calculate Expected Utility
    # EU_i = log(Σ_j exp(V_j + μ * I_j))
    EU_task2 = np.multiply(pop, np.log(sum_dest))

    return Vol_car, Vol_pt, Vol_slow, EU_task2

# %%
v_car, v_pt, v_slow, EU = Demand_nestlogit(
        car_time, car_cost, carparking, invt, waitt,
        transitprice, dist, param,
        np.matrix(landuse['pop']),
        np.matrix(landuse['emp']),
        np.matrix(landuse['car_ownership']))
print(f"Total Car Demand: {np.sum(v_car):,.0f}")
print(f"Total PT Demand: {np.sum(v_pt):,.0f}")
print(f"Total Slow Demand: {np.sum(v_slow):,.0f}")
print(f"Expected Utility: {np.sum(EU):,.0f}")
# Out:
# Result - Volume of Car: 486129.0961965784
# Result - Volume of PT: 263739.1262103094
# Result - Volume of Slow: 50131.77759311218
# Total Car Demand: 486,129
# Total PT Demand: 263,739
# Total Slow Demand: 50,132
# Expected Utility: 8,910,497

# %% [markdown]
# # Task III
# The expected utility $EU$ can be used as a welfare measure when the change between two different scenarios is analysed. If cost enters the utility functions $V$, the difference in expected utility  $EU$ between two different scenarios can be translated into a monetary terms and used as a measure for consumer surplus.
# Please write the expected maximum utility from the joint decision model.
#
# Another task is to divide the population into two categories: individuals who have access to a car and those who do not. For individuals with access to a car, the set of possible
# transport modes is $ \lbrace car,pt,slow \rbrace $. Without access to a car, the set is $\lbrace pt,slow \rbrace $.
# The demand is the total demand of these two groups of population.

# %%
def Demand_nestlogit_ownership(car_time, car_cost, car_park, inv_time, wait_time, pt_price, dist, parameter, pop, emp, own):

    # 1. Parameters Setting
    alpha_car   = parameter[0]
    beta_car    = parameter[1]
    gamma_car   = parameter[2]
    beta_inv    = parameter[3]
    beta_wait   = parameter[4]
    gamma_pt    = parameter[5]
    alpha_slow  = parameter[6]
    phi_dist    = parameter[7]
    mu          = parameter[8]
    theta       = parameter[9]

    pop = np.asmatrix(pop).transpose()
    own = np.asmatrix(own).transpose()
    emp = np.asmatrix(emp)

    # Ensure all time, cost, and distance arrays are ndarrays
    car_time = np.asmatrix(car_time)
    car_cost = np.asmatrix(car_cost)
    inv_time = np.asmatrix(inv_time)
    wait_time = np.asmatrix(wait_time)
    dist = np.asmatrix(dist)

    # 2. Utility Functions for each mode and attractions
    # Car: V = alpha + beta*t + gamma*c
    Vcar  = parameter[0] + (parameter[1] * car_time) + (parameter[2] * (car_cost + car_park))
    # PT: V = beta*t_inv + beta*t_wait + gamma*c
    Vpt   = (parameter[3] * inv_time) + (parameter[4] * wait_time) + (parameter[5] * pt_price)
    # Slow: V = alpha_slow + phi*dist
    Vslow = parameter[6] + (parameter[7] * dist)
    # Attractions Vj:
    Vj  = parameter[9] * np.log(emp)

    # 3. CAR OWNERS
    # 3.1 Calculate Logsum (I) and P(m|j) - three modes
    exp_car = np.exp(Vcar / mu)
    exp_pt = np.exp(Vpt / mu)
    exp_slow = np.exp(Vslow / mu)
    denom_own = exp_car + exp_pt + exp_slow
    Lj_own = np.log(denom_own + 1e-10)

    Pcar_own = exp_car / denom_own
    Ppt_own = exp_pt / denom_own
    Pslow_own = exp_slow / denom_own

    # 3.2 Calculate Marginal Probability from i to j
    V_dest_own = Vj + (mu * Lj_own)
    exp_dest_own = np.exp(V_dest_own)
    sum_dest_own = np.sum(exp_dest_own, axis=1)
    Pj_own = exp_dest_own / sum_dest_own
    # p_sum_own = np.sum(Pj_own, axis = 1)
    # print("Result - Marginal Probability from i to j is:", Pj)
    # print("Check - Sum of Marginal Probability:", p_sum_own)

    # 3.3 Calculate Joint Probability
    Pcar_j_own = np.multiply(Pj_own, Pcar_own)
    Ppt_j_own  = np.multiply(Pj_own, Ppt_own)
    Pslow_j_own = np.multiply(Pj_own, Pslow_own)
    # pj_sum_own = np.sum(Pcar_j_own, axis=1) + np.sum(Ppt_j_own, axis=1) + np.sum(Pslow_j_own, axis=1)
    # print("Check - Sum of Joint Probability:", pj_sum_own)

    # 3.4 Calculate the Demand
    pop_own = np.multiply(pop, own)
    Vol_car_own = np.multiply(pop_own, Pcar_j_own)
    Vol_pt_own = np.multiply(pop_own, Ppt_j_own)
    Vol_slow_own = np.multiply(pop_own, Pslow_j_own)
    Vol_sum_own = np.sum(Vol_car_own) + np.sum(Vol_pt_own) + np.sum(Vol_slow_own)

    # 3.5 Calculate Expected Utility
    # EU_i = log(Σ_j exp(V_j + μ * I_j))
    EU_own = np.multiply(pop_own, np.log(sum_dest_own))

    # 4. NON-CAR OWNERS
    # 4.1 Calculate Logsum (I) and P(m|j) - two modes
    denom_nocar = exp_pt + exp_slow
    Ij_nocar = np.log(denom_nocar + 1e-10)

    Ppt_nocar = exp_pt / denom_nocar
    Pslow_nocar = exp_slow / denom_nocar

    # 4.2 Calculate Marginal Probability from i to j
    V_dest_nocar = Vj + (mu * Ij_nocar)
    exp_dest_nocar = np.exp(V_dest_nocar)
    sum_dest_nocar = np.sum(exp_dest_nocar, axis=1)
    Pj_nocar = exp_dest_nocar / sum_dest_nocar

    # 4.3 Calculate Joint Probability
    Ppt_j_nocar = np.multiply(Pj_nocar, Ppt_nocar)
    Pslow_j_nocar = np.multiply(Pj_nocar, Pslow_nocar)

    # 4.4 Calculate the Demand
    pop_nocar = np. multiply(pop, (1 - own))
    Vol_pt_nocar = np.multiply(pop_nocar, Ppt_j_nocar)
    Vol_slow_nocar = np.multiply(pop_nocar, Pslow_j_nocar)

    # 4.5 Calculate Expected Utility
    EU_nocar = np.multiply(pop_nocar, np. log(sum_dest_nocar))

    # 5. TOTAL Volume
    Vol_car = Vol_car_own
    Vol_pt = Vol_pt_own + Vol_pt_nocar
    Vol_slow = Vol_slow_own + Vol_slow_nocar
    EU = EU_own + EU_nocar
    print("Result - Volume of Car:", Vol_car.sum())
    print("Result - Volume of PT:", Vol_pt.sum())
    print("Result - Volume of Slow:", Vol_slow.sum())

    return Vol_car, Vol_pt, Vol_slow, EU

# %%
# Settings: Max Iterations; Convergence Threshold; Smoothing Factors
maxiter = 100
maxdiff = 0.01
smoothing = 0.2
print("Start Iterations for Equilibrium:")

for iter in range(maxiter):
    car_time_old = car_time.copy()
    car_cost_old = car_cost.copy()

    # 1. Demand based on current travel time
    v_car, v_pt, v_slow, EU = Demand_nestlogit_ownership(
        car_time, car_cost, carparking, invt, waitt,
        transitprice, dist, param,
        np.array(landuse['pop']),
        np.array(landuse['emp']),
        np.array(landuse['car_ownership']))
    print(f"Total Car Demand: {np.sum(v_car):,.0f}")
    print(f"Total PT Demand: {np.sum(v_pt):,.0f}")
    print(f"Total Slow Demand: {np.sum(v_slow):,.0f}")

    # 2. Traffic Assignmnet
    G_next_car = Assignment.RouteAssignment(
        np.asarray(v_car), G_car, origin, destination,
        vot_car, cost_km, penalty_intra_car)
    G_next_pt = Assignment.TransitAssignment(
        np.asarray(v_pt), G_pt, origin, destination,
        vot_in, vot_wait)

    # 3. New Time and Cost
    car_time_new, car_cost_new, dist = Assignment.Skim_car(
        G_next_car, origin, destination, penalty_intra_car)

    # 4. MSA Smoothing
    car_time = car_time_new * smoothing + car_time_old * (1 - smoothing)
    car_cost = car_cost_new * smoothing + car_cost_old * (1 - smoothing)

    # 5. Convergence Signal
    diff = (np.mean((np.abs(car_time - car_time_old))))
    print(f"Iteration: {iter+1}\tDemand:{np.sum(v_car):.0f}, Difference in travel time:{diff:.4f}")
    if (diff < maxdiff) or (iter>=maxiter-1):
        print(f"\nConverged at iteration {iter+1}!")
        break

print(f"\nFinal Equilibrium Result:")
print(f"Car Trips: {np.sum(v_car):,.0f}")
print(f"PT Trips: {np.sum(v_pt):,.0f}")
print(f"Slow Trips: {np.sum(v_slow):,.0f}")
print(f"Expected Utility: {np.sum(EU):,.0f}")
# Out:
# Start Iterations for Equilibrium:
# Result - Volume of Car: 359573.7999397784
# Result - Volume of PT: 360725.1511450275
# Result - Volume of Slow: 79701.0489151942
# Total Car Demand: 359,574
# Total PT Demand: 360,725
# Total Slow Demand: 79,701
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times    Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  --------  ----------------------
#     1                  5.9187e+06                    5.9187e+06         0                       0
# ---------------------------------------------------------------------------------------------
# assignment: k = 2 relgap = 0.000000, AEC = 0.000000
# Iteration: 1	Demand:359574, Difference in travel time:2.0176
# Result - Volume of Car: 376270.23357223213
# Result - Volume of PT: 345990.12638880964
# Result - Volume of Slow: 77739.64003895814
# Total Car Demand: 376,270
# Total PT Demand: 345,990
# Total Slow Demand: 77,740
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times       Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  -----------  ----------------------
#     1                 6.27099e+06                   6.25345e+06  0.00280437                 40950.9
#     2                 6.25971e+06                   6.25599e+06  0.000595295                 9557.88
#     3                 6.25971e+06                   6.256e+06    0.000593489                 9548.55
#     4                 6.25971e+06                   6.25601e+06  0.000591687                 9539.22
#     5                 6.25971e+06                   6.25602e+06  0.00058989                  9529.91
#     6                 6.25971e+06                   6.25603e+06  0.000588097                 9520.6
#     7                 6.25971e+06                   6.25604e+06  0.000586307                 9511.3
#     8                 6.25971e+06                   6.25605e+06  0.000584522                 9502.02
#     9                 6.25971e+06                   6.25606e+06  0.000582742                 9492.74
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.000583, AEC = 0.009689
# Iteration: 2	Demand:376270, Difference in travel time:1.4562
# Result - Volume of Car: 391197.21618465654
# Result - Volume of PT: 332652.61705086933
# Result - Volume of Slow: 76150.16676447405
# Total Car Demand: 391,197
# Total PT Demand: 332,653
# Total Slow Demand: 76,150
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times       Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  -----------  ----------------------
#     1                 6.7895e+06                    6.75405e+06  0.00524992                  45679.9
#     2                 6.76743e+06                   6.76263e+06  0.000710598                 12802.9
#     3                 6.76743e+06                   6.76265e+06  0.000707766                 12790.4
#     4                 6.76743e+06                   6.76266e+06  0.00070494                  12777.9
#     5                 6.76743e+06                   6.76268e+06  0.000702122                 12765.4
#     6                 6.76743e+06                   6.7627e+06   0.00069931                  12752.9
#     7                 6.76743e+06                   6.76272e+06  0.000696506                 12740.5
#     8                 6.76743e+06                   6.76274e+06  0.000693708                 12728
#     9                 6.76743e+06                   6.76276e+06  0.000690917                 12715.6
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.000691, AEC = 0.011944
# Iteration: 3	Demand:391197, Difference in travel time:0.9632
# Result - Volume of Car: 401283.7397802063
# Result - Volume of PT: 323608.327998708
# Result - Volume of Slow: 75107.93222108575
# Total Car Demand: 401,284
# Total PT Demand: 323,608
# Total Slow Demand: 75,108
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times       Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  -----------  ----------------------
#     1                 7.26328e+06                   7.22519e+06  0.00527244                  48624.6
#     2                 7.24175e+06                   7.23712e+06  0.000640343                 12393.6
#     3                 7.24175e+06                   7.23714e+06  0.000637775                 12381.5
#     4                 7.24175e+06                   7.23716e+06  0.000635212                 12369.4
#     5                 7.24175e+06                   7.23718e+06  0.000632656                 12357.3
#     6                 7.24175e+06                   7.23719e+06  0.000630107                 12345.2
#     7                 7.24175e+06                   7.23721e+06  0.000627563                 12333.2
#     8                 7.24175e+06                   7.23723e+06  0.000625026                 12321.1
#     9                 7.24176e+06                   7.23725e+06  0.000622495                 12309.1
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.000622, AEC = 0.011227
# Iteration: 4	Demand:401284, Difference in travel time:0.5912
# Result - Volume of Car: 406388.8252672415
# Result - Volume of PT: 319075.457904881
# Result - Volume of Slow: 74535.71682787748
# Total Car Demand: 406,389
# Total PT Demand: 319,075
# Total Slow Demand: 74,536
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times       Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  -----------  ----------------------
#     1                 7.55218e+06                   7.51883e+06  0.00443542                  50001.4
#     2                 7.53514e+06                   7.53109e+06  0.000537366                 10889
#     3                 7.53514e+06                   7.53111e+06  0.00053537                  10878.3
#     4                 7.53514e+06                   7.53112e+06  0.000533379                 10867.7
#     5                 7.53514e+06                   7.53114e+06  0.000531392                 10857.1
#     6                 7.53514e+06                   7.53115e+06  0.00052941                  10846.5
#     7                 7.53514e+06                   7.53117e+06  0.000527434                 10835.9
#     8                 7.53514e+06                   7.53118e+06  0.000525461                 10825.3
#     9                 7.53514e+06                   7.5312e+06   0.000523494                 10814.8
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.000523, AEC = 0.009701
# Iteration: 5	Demand:406389, Difference in travel time:0.3648
# Result - Volume of Car: 408350.0840927513
# Result - Volume of PT: 317402.17091339594
# Result - Volume of Slow: 74247.74499385279
# Total Car Demand: 408,350
# Total PT Demand: 317,402
# Total Slow Demand: 74,248
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times       Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  -----------  ----------------------
#     1                 7.6799e+06                    7.65244e+06  0.00358767                 50387.4
#     2                 7.66675e+06                   7.66324e+06  0.000458154                 9496.85
#     3                 7.66675e+06                   7.66325e+06  0.000456597                 9487.58
#     4                 7.66675e+06                   7.66326e+06  0.000455043                 9478.31
#     5                 7.66675e+06                   7.66328e+06  0.000453493                 9469.05
#     6                 7.66675e+06                   7.66329e+06  0.000451947                 9459.81
#     7                 7.66675e+06                   7.6633e+06   0.000450404                 9450.57
#     8                 7.66675e+06                   7.66331e+06  0.000448865                 9441.34
#     9                 7.66675e+06                   7.66332e+06  0.00044733                  9432.12
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.000447, AEC = 0.008395
# Iteration: 6	Demand:408350, Difference in travel time:0.2379
# Result - Volume of Car: 408890.3259530874
# Result - Volume of PT: 317010.05704942864
# Result - Volume of Slow: 74099.61699748386
# Total Car Demand: 408,890
# Total PT Demand: 317,010
# Total Slow Demand: 74,100
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times      Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ----------  ----------------------
#     1                 7.723e+06                     7.683e+06    0.00520607                 72733.5
#     2                 7.69205e+06                   7.67206e+06  0.00260497                 25925.5
#     3                 7.69203e+06                   7.6721e+06   0.00259803                 25900.2
#     4                 7.69201e+06                   7.67213e+06  0.00259111                 25874.9
#     5                 7.69199e+06                   7.67216e+06  0.0025842                  25849.6
#     6                 7.69197e+06                   7.6722e+06   0.00257731                 25824.4
#     7                 7.69195e+06                   7.67223e+06  0.00257043                 25799.2
#     8                 7.69193e+06                   7.67226e+06  0.00256357                 25774
#     9                 7.69191e+06                   7.6723e+06   0.00255673                 25748.8
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.002557, AEC = 0.047974
# Iteration: 7	Demand:408890, Difference in travel time:0.1730
# Result - Volume of Car: 408866.93810866674
# Result - Volume of PT: 317122.1802514105
# Result - Volume of Slow: 74010.88163992272
# Total Car Demand: 408,867
# Total PT Demand: 317,122
# Total Slow Demand: 74,011
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times      Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ----------  ----------------------
#     1                 7.7451e+06                    7.69236e+06  0.00685617                 75687.9
#     2                 7.70377e+06                   7.68218e+06  0.00281034                 28752.5
#     3                 7.70375e+06                   7.68223e+06  0.00280226                 28724.4
#     4                 7.70373e+06                   7.68227e+06  0.0027942                  28696.4
#     5                 7.70371e+06                   7.68231e+06  0.00278615                 28668.4
#     6                 7.70369e+06                   7.68235e+06  0.00277813                 28640.4
#     7                 7.70367e+06                   7.68239e+06  0.00277012                 28612.4
#     8                 7.70365e+06                   7.68243e+06  0.00276213                 28584.5
#     9                 7.70363e+06                   7.68247e+06  0.00275416                 28556.5
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.002754, AEC = 0.051750
# Iteration: 8	Demand:408867, Difference in travel time:0.1259
# Result - Volume of Car: 408808.6983682801
# Result - Volume of PT: 317236.1773878781
# Result - Volume of Slow: 73955.12424384175
# Total Car Demand: 408,809
# Total PT Demand: 317,236
# Total Slow Demand: 73,955
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times      Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ----------  ----------------------
#     1                 7.75952e+06                   7.69723e+06  0.00809196                 77091
#     2                 7.71006e+06                   7.68729e+06  0.00296201                 30640.7
#     3                 7.71003e+06                   7.68733e+06  0.00295302                 30610.7
#     4                 7.71001e+06                   7.68738e+06  0.00294406                 30580.8
#     5                 7.70999e+06                   7.68743e+06  0.00293512                 30551
#     6                 7.70997e+06                   7.68748e+06  0.0029262                  30521.1
#     7                 7.70995e+06                   7.68752e+06  0.00291729                 30491.3
#     8                 7.70993e+06                   7.68757e+06  0.00290841                 30461.6
#     9                 7.70991e+06                   7.68762e+06  0.00289955                 30431.8
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.002900, AEC = 0.054526
# Iteration: 9	Demand:408809, Difference in travel time:0.0944
# Result - Volume of Car: 408746.66583691334
# Result - Volume of PT: 317333.4415577619
# Result - Volume of Slow: 73919.89260532468
# Total Car Demand: 408,747
# Total PT Demand: 317,333
# Total Slow Demand: 73,920
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times      Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ----------  ----------------------
#     1                 7.76913e+06                   7.69953e+06  0.00903957                 78100.3
#     2                 7.71316e+06                   7.6894e+06   0.00309004                 32109.6
#     3                 7.71314e+06                   7.68945e+06  0.00308031                 32078.2
#     4                 7.71312e+06                   7.68951e+06  0.0030706                  32046.9
#     5                 7.7131e+06                    7.68956e+06  0.00306091                 32015.6
#     6                 7.71307e+06                   7.68961e+06  0.00305125                 31984.3
#     7                 7.71305e+06                   7.68966e+06  0.0030416                  31953.1
#     8                 7.71303e+06                   7.68972e+06  0.00303199                 31921.9
#     9                 7.71301e+06                   7.68977e+06  0.00302239                 31890.7
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.003022, AEC = 0.056860
# Iteration: 10	Demand:408747, Difference in travel time:0.0717
# Result - Volume of Car: 408696.2597204384
# Result - Volume of PT: 317406.79618402536
# Result - Volume of Slow: 73896.94409553627
# Total Car Demand: 408,696
# Total PT Demand: 317,407
# Total Slow Demand: 73,897
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times      Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ----------  ----------------------
#     1                 7.7761e+06                    7.70084e+06  0.00977342                 78843.2
#     2                 7.71489e+06                   7.69049e+06  0.00317285                 33185
#     3                 7.71487e+06                   7.69054e+06  0.00316256                 33152.6
#     4                 7.71484e+06                   7.6906e+06   0.0031523                  33120.2
#     5                 7.71482e+06                   7.69066e+06  0.00314206                 33087.9
#     6                 7.7148e+06                    7.69071e+06  0.00313184                 33055.5
#     7                 7.71478e+06                   7.69077e+06  0.00312165                 33023.3
#     8                 7.71476e+06                   7.69083e+06  0.00311148                 32991
#     9                 7.71474e+06                   7.69088e+06  0.00310134                 32958.8
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.003101, AEC = 0.058361
# Iteration: 11	Demand:408696, Difference in travel time:0.0546
# Result - Volume of Car: 408660.53577131854
# Result - Volume of PT: 317457.9783941067
# Result - Volume of Slow: 73881.48583457479
# Total Car Demand: 408,661
# Total PT Demand: 317,458
# Total Slow Demand: 73,881
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times      Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ----------  ----------------------
#     1                 7.78142e+06                   7.70183e+06  0.0103337                  79389.8
#     2                 7.71613e+06                   7.69116e+06  0.00324679                 34035.3
#     3                 7.7161e+06                    7.69121e+06  0.00323604                 34002
#     4                 7.71608e+06                   7.69127e+06  0.00322531                 33968.8
#     5                 7.71606e+06                   7.69133e+06  0.00321462                 33935.7
#     6                 7.71604e+06                   7.69139e+06  0.00320394                 33902.5
#     7                 7.71601e+06                   7.69145e+06  0.0031933                  33869.4
#     8                 7.71599e+06                   7.69151e+06  0.00318267                 33836.3
#     9                 7.71597e+06                   7.69157e+06  0.00317208                 33803.3
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.003172, AEC = 0.059703
# Iteration: 12	Demand:408661, Difference in travel time:0.0419
# Result - Volume of Car: 408636.01908322895
# Result - Volume of PT: 317493.168265103
# Result - Volume of Slow: 73870.81265166803
# Total Car Demand: 408,636
# Total PT Demand: 317,493
# Total Slow Demand: 73,871
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times      Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ----------  ----------------------
#     1                 7.78559e+06                   7.70265e+06  0.0107677                  79800.3
#     2                 7.71707e+06                   7.69169e+06  0.00330019                 34678.8
#     3                 7.71705e+06                   7.69175e+06  0.00328908                 34645
#     4                 7.71702e+06                   7.69181e+06  0.00327801                 34611.1
#     5                 7.717e+06                     7.69187e+06  0.00326696                 34577.3
#     6                 7.71698e+06                   7.69193e+06  0.00325594                 34543.6
#     7                 7.71696e+06                   7.692e+06    0.00324494                 34509.8
#     8                 7.71693e+06                   7.69206e+06  0.00323397                 34476.1
#     9                 7.71691e+06                   7.69212e+06  0.00322303                 34442.5
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.003223, AEC = 0.060670
# Iteration: 13	Demand:408636, Difference in travel time:0.0323
# Result - Volume of Car: 408620.1023698565
# Result - Volume of PT: 317516.6541759001
# Result - Volume of Slow: 73863.24345424342
# Total Car Demand: 408,620
# Total PT Demand: 317,517
# Total Slow Demand: 73,863
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times      Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ----------  ----------------------
#     1                 7.7889e+06                    7.70338e+06  0.0111021                  80109.3
#     2                 7.71783e+06                   7.69225e+06  0.00332572                 35126
#     3                 7.71781e+06                   7.69231e+06  0.00331438                 35091.7
#     4                 7.71778e+06                   7.69238e+06  0.00330307                 35057.5
#     5                 7.71776e+06                   7.69244e+06  0.00329178                 35023.2
#     6                 7.71774e+06                   7.6925e+06   0.00328052                 34989
#     7                 7.71772e+06                   7.69257e+06  0.00326929                 34954.9
#     8                 7.71769e+06                   7.69263e+06  0.00325809                 34920.7
#     9                 7.71767e+06                   7.6927e+06   0.00324691                 34886.6
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.003247, AEC = 0.061126
# Iteration: 14	Demand:408620, Difference in travel time:0.0249
# Result - Volume of Car: 408610.59668833896
# Result - Volume of PT: 317531.67952671146
# Result - Volume of Slow: 73857.72378494956
# Total Car Demand: 408,611
# Total PT Demand: 317,532
# Total Slow Demand: 73,858
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times      Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ----------  ----------------------
#     1                 7.7915e+06                    7.70404e+06  0.011352                   80336.4
#     2                 7.71856e+06                   7.69262e+06  0.00337113                 35539.5
#     3                 7.71853e+06                   7.69269e+06  0.00335955                 35504.8
#     4                 7.71851e+06                   7.69275e+06  0.00334799                 35470.1
#     5                 7.71849e+06                   7.69282e+06  0.00333647                 35435.4
#     6                 7.71846e+06                   7.69289e+06  0.00332497                 35400.8
#     7                 7.71844e+06                   7.69295e+06  0.0033135                  35366.3
#     8                 7.71842e+06                   7.69302e+06  0.00330205                 35331.7
#     9                 7.7184e+06                    7.69308e+06  0.00329064                 35297.2
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.003291, AEC = 0.061954
# Iteration: 15	Demand:408611, Difference in travel time:0.0194
# Result - Volume of Car: 408604.01551303815
# Result - Volume of PT: 317542.294084746
# Result - Volume of Slow: 73853.69040221589
# Total Car Demand: 408,604
# Total PT Demand: 317,542
# Total Slow Demand: 73,854
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times      Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ----------  ----------------------
#     1                 7.79359e+06                   7.70458e+06  0.0115527                  80515.4
#     2                 7.71906e+06                   7.69309e+06  0.00337607                 35775.9
#     3                 7.71904e+06                   7.69316e+06  0.00336437                 35740.9
#     4                 7.71902e+06                   7.69322e+06  0.0033527                  35706
#     5                 7.71899e+06                   7.69329e+06  0.00334105                 35671.2
#     6                 7.71897e+06                   7.69336e+06  0.00332943                 35636.3
#     7                 7.71895e+06                   7.69342e+06  0.00331784                 35601.5
#     8                 7.71893e+06                   7.69349e+06  0.00330628                 35566.8
#     9                 7.71891e+06                   7.69356e+06  0.00329475                 35532
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.003295, AEC = 0.062036
# Iteration: 16	Demand:408604, Difference in travel time:0.0149
# Result - Volume of Car: 408601.00664667
# Result - Volume of PT: 317548.37935885024
# Result - Volume of Slow: 73850.61399447973
# Total Car Demand: 408,601
# Total PT Demand: 317,548
# Total Slow Demand: 73,851
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times      Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ----------  ----------------------
#     1                 7.79522e+06                   7.70509e+06  0.0116975                  80643.6
#     2                 7.71957e+06                   7.69346e+06  0.00339413                 35990.4
#     3                 7.71955e+06                   7.69353e+06  0.0033823                  35955.2
#     4                 7.71953e+06                   7.69359e+06  0.00337051                 35920.1
#     5                 7.7195e+06                    7.69366e+06  0.00335874                 35885
#     6                 7.71948e+06                   7.69373e+06  0.003347                   35850
#     7                 7.71946e+06                   7.6938e+06   0.00333529                 35815
#     8                 7.71943e+06                   7.69386e+06  0.00332361                 35780
#     9                 7.71941e+06                   7.69393e+06  0.00331195                 35745
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.003312, AEC = 0.062364
# Iteration: 17	Demand:408601, Difference in travel time:0.0117
# Result - Volume of Car: 408599.0924336747
# Result - Volume of PT: 317552.6204339321
# Result - Volume of Slow: 73848.28713239325
# Total Car Demand: 408,599
# Total PT Demand: 317,553
# Total Slow Demand: 73,848
# ROUTE ASSIGNMENT
# ---------------------------------------------------------------------------------------------
#   ITR    Total System Travel Time    Shortest Path Travel Times      Relgap    Changes in in volume
# -----  --------------------------  ----------------------------  ----------  ----------------------
#     1                 7.79649e+06                   7.70549e+06  0.0118098                  80741.8
#     2                 7.71999e+06                   7.69368e+06  0.00342012                 36191.9
#     3                 7.71997e+06                   7.69375e+06  0.00340817                 36156.6
#     4                 7.71995e+06                   7.69382e+06  0.00339625                 36121.2
#     5                 7.71992e+06                   7.69388e+06  0.00338436                 36086
#     6                 7.7199e+06                    7.69395e+06  0.00337249                 36050.7
#     7                 7.71988e+06                   7.69402e+06  0.00336066                 36015.5
#     8                 7.71985e+06                   7.69409e+06  0.00334885                 35980.4
#     9                 7.71983e+06                   7.69416e+06  0.00333708                 35945.2
# ---------------------------------------------------------------------------------------------
# assignment: k = 10 relgap = 0.003337, AEC = 0.062839
# Iteration: 18	Demand:408599, Difference in travel time:0.0092
#
# Converged at iteration 18!
#
# Final Equilibrium Result:
# Car Trips: 408,599
# PT Trips: 317,553
# Slow Trips: 73,848
# Expected Utility: 8,772,483

# %%
from Effect import Effect
Effect(v_car, v_pt, v_slow, dist, carparking, transitprice, EU)
# Out:
#                     INFORMATION
# Car Trips                408599
# Transit Trips            317553
# Slow Trips                73848
# Total trips              800000
# Distance Travelled        71152
# Expected Utility        8772483

# %%
avg_car_ownership = np.mean(landuse['car_ownership'])
print(f"Average Car Ownership: {avg_car_ownership:.2%}")
# Out:
# Average Car Ownership: 73.60%

# %% [markdown]
# # Bandwidth Map

# %%
Visualize(G_next_car, G_next_pt, zones, title="")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_98130540b743c9beadee6268423fc9e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#                 &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_98130540b743c9beadee6268423fc9e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_98130540b743c9beadee6268423fc9e9 = L.map(
#                 &quot;map_98130540b743c9beadee6268423fc9e9&quot;,
#                 {
#                     center: [59.33429725815369, 18.074580506480082],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_98130540b743c9beadee6268423fc9e9);
#
#
#
#
#
#             var tile_layer_2349a60e316f731754358165e450bdbb = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2349a60e316f731754358165e450bdbb.addTo(map_98130540b743c9beadee6268423fc9e9);
#
#
#             map_98130540b743c9beadee6268423fc9e9.fitBounds(
#                 [[59.22725242579792, 17.760692003425188], [59.44134209050946, 18.388469009534976]],
#                 {}
#             );
#
#
#         function geo_json_d749a83d1bd1c3a4e547e79d0d0837ff_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_d749a83d1bd1c3a4e547e79d0d0837ff_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_d749a83d1bd1c3a4e547e79d0d0837ff_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_d749a83d1bd1c3a4e547e79d0d0837ff_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_d749a83d1bd1c3a4e547e79d0d0837ff_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_d749a83d1bd1c3a4e547e79d0d0837ff.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_d749a83d1bd1c3a4e547e79d0d0837ff_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_d749a83d1bd1c3a4e547e79d0d0837ff = L.geoJson(null, {
#                 onEachFeature: geo_json_d749a83d1bd1c3a4e547e79d0d0837ff_onEachFeature,
#
#                 style: geo_json_d749a83d1bd1c3a4e547e79d0d0837ff_styler,
#                 pointToLayer: geo_json_d749a83d1bd1c3a4e547e79d0d0837ff_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_d749a83d1bd1c3a4e547e79d0d0837ff_add (data) {
#             geo_json_d749a83d1bd1c3a4e547e79d0d0837ff
#                 .addData(data);
#         }
#             geo_json_d749a83d1bd1c3a4e547e79d0d0837ff_add({&quot;bbox&quot;: [17.760692003425188, 59.22725242579792, 18.388469009534976, 59.44134209050946], &quot;features&quot;: [{&quot;bbox&quot;: [17.888449229398596, 59.33936467432812, 18.05854435314131, 59.440283880183806], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[17.99926189055947, 59.34097701581949], [17.998281666750778, 59.3407689948803], [17.996356534152998, 59.34144786207281], [17.993343631062963, 59.342432332102284], [17.99062030018352, 59.343277261094016], [17.989494882762237, 59.34354747977749], [17.988854306784262, 59.34370189512002], [17.988404075747276, 59.343808218465895], [17.987385806019535, 59.344103655629084], [17.985110002349966, 59.344527877712736], [17.983195898

# %%
Visualize(G_next_car, G_next_pt, zones, title="Traffic Flows", show_text_threshold=10000)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0b182e5a7051d12b59fe64416503cba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#                 &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Traffic Flows&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0b182e5a7051d12b59fe64416503cba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0b182e5a7051d12b59fe64416503cba = L.map(
#                 &quot;map_f0b182e5a7051d12b59fe64416503cba&quot;,
#                 {
#                     center: [59.33429725815369, 18.074580506480082],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_f0b182e5a7051d12b59fe64416503cba);
#
#
#
#
#
#             var tile_layer_b63e6a2ad4faeeb83ca2cd94dcc285a2 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b63e6a2ad4faeeb83ca2cd94dcc285a2.addTo(map_f0b182e5a7051d12b59fe64416503cba);
#
#
#             map_f0b182e5a7051d12b59fe64416503cba.fitBounds(
#                 [[59.22725242579792, 17.760692003425188], [59.44134209050946, 18.388469009534976]],
#                 {}
#             );
#
#
#         function geo_json_5ac9147bf03ea9b618becbbd35284c8c_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_5ac9147bf03ea9b618becbbd35284c8c_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_5ac9147bf03ea9b618becbbd35284c8c_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_5ac9147bf03ea9b618becbbd35284c8c_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_5ac9147bf03ea9b618becbbd35284c8c_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_5ac9147bf03ea9b618becbbd35284c8c.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_5ac9147bf03ea9b618becbbd35284c8c_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_5ac9147bf03ea9b618becbbd35284c8c = L.geoJson(null, {
#                 onEachFeature: geo_json_5ac9147bf03ea9b618becbbd35284c8c_onEachFeature,
#
#                 style: geo_json_5ac9147bf03ea9b618becbbd35284c8c_styler,
#                 pointToLayer: geo_json_5ac9147bf03ea9b618becbbd35284c8c_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_5ac9147bf03ea9b618becbbd35284c8c_add (data) {
#             geo_json_5ac9147bf03ea9b618becbbd35284c8c
#                 .addData(data);
#         }
#             geo_json_5ac9147bf03ea9b618becbbd35284c8c_add({&quot;bbox&quot;: [17.760692003425188, 59.22725242579792, 18.388469009534976, 59.44134209050946], &quot;features&quot;: [{&quot;bbox&quot;: [17.888449229398596, 59.33936467432812, 18.05854435314131, 59.440283880183806], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[17.99926189055947, 59.34097701581949], [17.998281666750778, 59.3407689948803], [17.996356534152998, 59.34144786207281], [17.993343631062963, 59.342432332102284], [17.99062030018352, 59.343277261094016], [17.989494882762237, 59.34354747977749], [17.988854306784262, 59.34370189512002], [17.988404075747276, 59.343808218465895], [17.987385806019535, 59.344103655629084], [17.985110002349966, 59.344527877712736],

# %% [markdown]
# # Social-Economic Demographics

# %% [markdown]
# ## Population and Employment Distribution Map

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

zones_gdf = gpd.read_file("zones.geojson")
landuse_clean = landuse.copy()
if 'geometry' in landuse_clean.columns:
    landuse_clean = landuse_clean.drop(columns=['geometry'])
zones_gdf = zones_gdf.merge(landuse_clean, on='area')

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(35, 10))
zones_gdf.plot(column='pop',
               ax=ax1,
               legend=True,
               cmap='OrRd',
               edgecolor='black',
               linewidth=0.5,
               legend_kwds={'label': "Number of Residents"})
cbar1 = ax1.get_figure().get_axes()[2]
cbar1.set_ylabel("Number of Residents", fontsize=25, labelpad=25)
cbar1.tick_params(labelsize=25)
ax1.set_title('Population Distribution (Total Count)', fontsize=28, fontweight='bold')
ax1.axis('off')

for idx, row in zones_gdf.iterrows():
    ax1.annotate(text=str(idx),
                 xy=(row.geometry.centroid.x, row.geometry.centroid.y),
                 ha='center', fontsize=25, color='black', weight='bold')

zones_gdf.plot(column='emp',
               ax=ax2,
               legend=True,
               cmap='BuPu',
               edgecolor='black',
               linewidth=0.5,
               legend_kwds={'label': "Number of Jobs"})
cbar2 = ax2.get_figure().get_axes()[3]
cbar2.set_ylabel("Number of Jobs", fontsize=25, labelpad=25)
cbar2.tick_params(labelsize=25)
ax2.set_title('Employment Distribution (Total Count)', fontsize=28, fontweight='bold')
ax2.axis('off')

for idx, row in zones_gdf.iterrows():
    ax2.annotate(text=str(idx),
                 xy=(row.geometry.centroid.x, row.geometry.centroid.y),
                 ha='center', fontsize=25, color='black', weight='bold')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))

zones = landuse['area']
x = np.arange(len(zones))
width = 0.35

plt.bar(x - width/2, landuse['pop'], width, label='Population (Residents)')
plt.bar(x + width/2, landuse['emp'], width, label='Employment (Jobs)')

plt.xlabel('Zone Area')
plt.ylabel('Count')
plt.title('Stockholm 2020: Imbalance between Population and Employment')
plt.xticks(x, zones, rotation=45)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Income and Car Ownership Distribution Map

# %%
zones_gdf = gpd.read_file("zones.geojson")
landuse_clean = landuse.copy()
if 'geometry' in landuse_clean.columns:
    landuse_clean = landuse_clean.drop(columns=['geometry'])
zones_gdf = zones_gdf.merge(landuse_clean, on='area')

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(35, 10))

zones_gdf.plot(column='inc',
               ax=ax1,
               legend=True,
               cmap='Greens',
               edgecolor='black',
               linewidth=0.5,
               legend_kwds={
                   'label': "Average Yearly Income (kSEK)",
                   'orientation': "vertical",
                   'shrink': 0.8
               })

cbar1 = ax1.get_figure().get_axes()[2]
cbar1.set_ylabel("Average Income (kSEK)", fontsize=22, labelpad=22)
cbar1.tick_params(labelsize=20)
ax1.set_title('Spatial Distribution of Income', fontsize=25, fontweight='bold')
ax1.axis('off')

for idx, row in zones_gdf.iterrows():
    ax1.annotate(text=str(idx),
                 xy=(row.geometry.centroid.x, row.geometry.centroid.y),
                 ha='center', fontsize=25, color='black', weight='bold')

zones_gdf.plot(column='car_ownership',
               ax=ax2,
               legend=True,
               cmap='Reds',
               edgecolor='black',
               linewidth=0.5,
               legend_kwds={
                   'label': "Car Ownership Probability",
                   'orientation': "vertical",
                   'shrink': 0.8
               })

cbar2 = ax2.get_figure().get_axes()[3]
cbar2.set_ylabel("Probability (0-1)", fontsize=22, labelpad=22)
cbar2.tick_params(labelsize=20)
ax2.set_title('Spatial Distribution of Car Ownership', fontsize=25, fontweight='bold')
ax2.axis('off')

for idx, row in zones_gdf.iterrows():
    ax2.annotate(text=str(idx),
                 xy=(row.geometry.centroid.x, row.geometry.centroid.y),
                 ha='center', fontsize=25, color='black', weight='bold')

plt.tight_layout()
plt.show()
